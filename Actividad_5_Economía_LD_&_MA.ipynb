# %% [markdown]
# # Importar  librerías e importar datos

# %%
import pandas as pd

B2024 = pd.read_csv("2024.csv", sep=",")
B2025 = pd.read_csv("2025.csv", sep=";")

print(B2024.head())
print(B2025.head())

print(B2024.shape)
print(B2025.shape)
# Out:
#     per  hogar  dpto  p3271  p6040  p6030s3  p3042  p3042s1  p3042s2  inglabo
# 0  2024      1    15      1     50   1974.0      3        5      NaN        0
# 1  2024      1    15      2     32   1992.0      3        5      NaN   600000
# 2  2024      1    15      1     63   1960.0      3        5      NaN  1300000
# 3  2024      1    15      1     31   1993.0      3        5      NaN  2800000
# 4  2024      1    15      1     33   1991.0      3        4      NaN  1300000
#     per  hogar  dpto  p3271  p6040  p6030s3  p3042  p3042s1  p3042s2  \
# 0  2025      1     8      1     32   1993.0      5        2      NaN
# 1  2025      1     8      2     28   1997.0      8        4    419.0
# 2  2025      1     8      1     75   1950.0      1        0      NaN
# 3  2025      1     8      1     68   1957.0      3        5      NaN
# 4  2025      1     8      1     66   1959.0      3        5      NaN
#
#      inglabo
# 0  1200000.0
# 1        NaN
# 2  2000000.0
# 3  1800000.0
# ...

# %% [markdown]
# # Conocer la estructura

# %%
print(B2024.columns)
print(B2025.columns)
# Out:
# Index(['per', 'hogar', 'dpto', 'p3271', 'p6040', 'p6030s3', 'p3042', 'p3042s1',
#        'p3042s2', 'inglabo'],
#       dtype='object')
# Index(['per', 'hogar', 'dpto', 'p3271', 'p6040', 'p6030s3', 'p3042', 'p3042s1',
#        'p3042s2', 'inglabo'],
#       dtype='object')
